# %% [markdown]
# # README
#
# This notebooks explores the titanic dataset from Kaggle. It is my seond submission, but this time feature engineering was not used.
# Author: Sultan Aitekenov sultanaitekenov@gmail.com
# Here is the implementation for the titanic challenge from Kaggle. https://www.kaggle.com/competitions/titanic/data

# %% [markdown]
# # Import modules

# %%
import pandas as pd
import re

# %% [markdown]
# # Process data

# %%
# train data
train_df = pd.read_csv('data/train.csv')
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# process data
# replace male and female
train_df.replace(['male', 'female'], [1,0], inplace=True)
# remove passenger id
train_df.drop(labels=['PassengerId', 'Name'], axis=1, inplace=True)
# apply hot encoding for Embarked
train_df = pd.get_dummies(train_df, columns=['Embarked'])
# drop Survived
y_train_df = train_df.Survived
x_train_df = train_df.drop(labels=["Survived"], axis=1, inplace=False)

# %%
x_train_df
# Out:
#      Pclass  Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0         3    1  22.0      1      0         A/5 21171   7.2500   NaN
# 1         1    0  38.0      1      0          PC 17599  71.2833   C85
# 2         3    0  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3         1    0  35.0      1      0            113803  53.1000  C123
# 4         3    1  35.0      0      0            373450   8.0500   NaN
# ..      ...  ...   ...    ...    ...               ...      ...   ...
# 886       2    1  27.0      0      0            211536  13.0000   NaN
# 887       1    0  19.0      0      0            112053  30.0000   B42
# 888       3    0   NaN      1      2        W./C. 6607  23.4500   NaN
# 889       1    1  26.0      0      0            111369  30.0000  C148
# 890       3    1  32.0      0      0            370376   7.7500   NaN
#
#      Embarked_C  Embarked_Q  Embarked_S
# 0             0           0           1
# 1             1           0           0
# ...

# %%
# extract cabin letters and apply one hot encoding
Cabin_letter = []

for item in x_train_df.Cabin:
    if type(item) == str:
        pattern = '([A-Z])'
        letter = re.findall(pattern, str(item), flags=1)[0]
        Cabin_letter.append(letter)
    else:
        Cabin_letter.append(None)

x_train_df["Cabin_letter"] = Cabin_letter
x_train_df = pd.get_dummies(x_train_df, columns=['Cabin_letter'])

# %%
# extract ticket letters and apply one hot encoding
Ticket_letter = []

for item in x_train_df.Ticket:
    
    split = item.split(" ")
    if len(split) >= 2:
        Ticket_letter.append(split[0])
    else:
        Ticket_letter.append(None)
        
x_train_df["Ticket_letter"] = Ticket_letter
x_train_df = pd.get_dummies(x_train_df, columns=['Ticket_letter'])

# %%
x_train_df.drop(labels=['Ticket', 'Cabin'], axis=1, inplace = True)

x_train_df

# %%
x_train_df
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare  Embarked_C  Embarked_Q  \
# 0         3    1  22.0      1      0   7.2500           0           0
# 1         1    0  38.0      1      0  71.2833           1           0
# 2         3    0  26.0      0      0   7.9250           0           0
# 3         1    0  35.0      1      0  53.1000           0           0
# 4         3    1  35.0      0      0   8.0500           0           0
# ..      ...  ...   ...    ...    ...      ...         ...         ...
# 886       2    1  27.0      0      0  13.0000           0           0
# 887       1    0  19.0      0      0  30.0000           0           0
# 888       3    0   NaN      1      2  23.4500           0           0
# 889       1    1  26.0      0      0  30.0000           1           0
# 890       3    1  32.0      0      0   7.7500           0           1
#
#      Embarked_S  Cabin_letter_A  ...  Ticket_letter_SOTON/O.Q.  \
# ...

# %% [markdown]
# # Train ANN

# %%
x_train_df
